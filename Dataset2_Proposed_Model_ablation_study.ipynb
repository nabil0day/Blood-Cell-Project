# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Dense, InputLayer
import numpy as np
from PIL import Image
from tensorflow.keras.optimizers import Adam
import os
##from tensorflow.keras.layers.experimental.preprocessing import RandomFlip, RandomRotation, RandomZoom
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.applications.vgg19 import preprocess_input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, BatchNormalization, MaxPooling2D, Flatten, Dropout, Dense, Input
from tensorflow.keras.regularizers import l2
from keras import regularizers
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import seaborn as sns
from tensorflow.keras.models import Model

# %%
BATCH_SIZE = 16
IMAGE_SIZE = 128

# %%
def preprocess_image(image, label):
    image = tf.keras.applications.vgg19.preprocess_input(image)

    image = tf.image.resize(image, (IMAGE_SIZE, IMAGE_SIZE))

    return image, label

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive/"
# Out:
# 'Colab Notebooks'   Dataset1.zip   dataset3.zip   dataset.zip
#  dataset_1.zip	    Dataset2.zip   dataset4.zip   fake_news_dataset.zip

# %%
import zipfile

# Define the path to the zip file and the extraction directory
zip_file_path = '/content/drive/My Drive/Dataset2.zip'
extraction_path = '/content/Dataset'

# Unzip the file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extraction_path)

# %%
dataset_path = "/content/Dataset"

# %%
full_dataset = tf.keras.preprocessing.image_dataset_from_directory(
    dataset_path,
    seed=123,
    shuffle=True,
    image_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=BATCH_SIZE
).map(preprocess_image)
dataset_size = tf.data.experimental.cardinality(full_dataset).numpy()
subset_size = int(1.0 * dataset_size)

# Take 20% of the dataset
dataset = full_dataset.take(subset_size)
# Out:
# Found 5000 files belonging to 5 classes.

# %%
class_names = sorted(os.listdir(dataset_path))

print(class_names)
# Out:
# ['basophil', 'erythroblast', 'monocyte', 'myeloblast', 'seg_neutrophil']

# %%
for image_batch, labels_batch in dataset.take(1):
    print(image_batch.shape)
    print(labels_batch.numpy())
# Out:
# (16, 128, 128, 3)
# [4 1 1 2 1 3 3 0 0 0 1 0 1 4 0 3]

# %%
for images, labels in dataset.take(1):
    plt.figure(figsize=(10, 10))

    num_images = min(10, images.shape[0])

    for i in range(num_images):
        ax = plt.subplot(4, 5, i + 1)
        img = images[i].numpy()

        if img.min() < 0 or img.max() > 1:
            img = ((img - img.min()) / (img.max() - img.min()) * 255).astype("uint8")
        else:
            img = (img * 255).astype("uint8")

        plt.imshow(img)
        plt.title(int(labels[i]))
        plt.axis("off")

    plt.show()
    break

# %%
len(dataset)
# Out:
# 313

# %%
def get_dataset_partitions_tf(ds, train_split=0.7, val_split=0.15, test_split=0.15, shuffle=True, shuffle_size=10000):
    assert (train_split + test_split + val_split) == 1

    ds_size = len(ds)

    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)

    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)

    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)

    return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)

# %%
len(train_ds)
# Out:
# 219

# %%
len(val_ds)
# Out:
# 46

# %%
len(test_ds)
# Out:
# 48

# %%
def custom_augmentation(image, label):

    # Random flip
    image = tf.image.random_flip_left_right(image)

    #Random brightness and contrast adjustment
    # image = tf.image.random_brightness(image, max_delta=0.1)
    # image = tf.image.random_contrast(image, lower=0.9, upper=1.0)

    # Random rotation
    image = tf.image.rot90(image, k=tf.random.uniform(shape=[], minval=0, maxval=4, dtype=tf.int32))

    return image, label

train_ds = train_ds.map(custom_augmentation, num_parallel_calls=tf.data.AUTOTUNE)

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(tf.data.AUTOTUNE)
val_ds = val_ds.cache().prefetch(tf.data.AUTOTUNE)
test_ds = test_ds.cache().prefetch(tf.data.AUTOTUNE)

# %%
# from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Reshape, multiply

# def se_block(input_tensor, reduction_ratio=8):
#     """ Squeeze-and-Excitation Block """
#     channels = input_tensor.shape[-1]  # Number of channels
#     se = GlobalAveragePooling2D()(input_tensor)  # Squeeze operation
#     se = Dense(channels // reduction_ratio, activation='relu')(se)  # Bottleneck layer
#     se = Dense(channels, activation='sigmoid')(se)  # Scale each channel
#     se = Reshape((1, 1, channels))(se)  # Reshape to broadcast
#     return multiply([input_tensor, se])  # Recalibrate the feature maps

# %%
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras import regularizers
import tensorflow.keras.backend as K
import pandas as pd

# Base components
def cbam_block(x, ratio=8):
    channel = x.shape[-1]

    # Channel Attention
    avg_pool = GlobalAveragePooling2D()(x)
    max_pool = GlobalMaxPooling2D()(x)
    shared_dense_one = Dense(channel // ratio, activation='relu', kernel_initializer='he_normal')
    shared_dense_two = Dense(channel, activation='sigmoid', kernel_initializer='he_normal')

    avg_out = shared_dense_two(shared_dense_one(avg_pool))
    max_out = shared_dense_two(shared_dense_one(max_pool))

    channel_attention = Add()([avg_out, max_out])
    channel_attention = Activation('sigmoid')(channel_attention)
    x = Multiply()([x, channel_attention])

    # Spatial Attention
    avg_pool = Lambda(lambda x: K.mean(x, axis=3, keepdims=True))(x)
    max_pool = Lambda(lambda x: K.max(x, axis=3, keepdims=True))(x)
    concat = Concatenate(axis=3)([avg_pool, max_pool])
    spatial_attention = Conv2D(1, kernel_size=7, strides=1, padding='same', activation='sigmoid')(concat)
    x = Multiply()([x, spatial_attention])

    return x

# Channel attention only
def channel_attention_only(x, ratio=8):
    channel = x.shape[-1]

    avg_pool = GlobalAveragePooling2D()(x)
    max_pool = GlobalMaxPooling2D()(x)
    shared_dense_one = Dense(channel // ratio, activation='relu', kernel_initializer='he_normal')
    shared_dense_two = Dense(channel, activation='sigmoid', kernel_initializer='he_normal')

    avg_out = shared_dense_two(shared_dense_one(avg_pool))
    max_out = shared_dense_two(shared_dense_one(max_pool))

    channel_attention = Add()([avg_out, max_out])
    channel_attention = Activation('sigmoid')(channel_attention)
    x = Multiply()([x, channel_attention])

    return x

# Spatial attention only
def spatial_attention_only(x):
    avg_pool = Lambda(lambda x: K.mean(x, axis=3, keepdims=True))(x)
    max_pool = Lambda(lambda x: K.max(x, axis=3, keepdims=True))(x)
    concat = Concatenate(axis=3)([avg_pool, max_pool])
    spatial_attention = Conv2D(1, kernel_size=7, strides=1, padding='same', activation='sigmoid')(concat)
    x = Multiply()([x, spatial_attention])

    return x

# Residual block variations
def residual_block(x, filters, attention_type='cbam', use_residual=True):
    if use_residual:
        shortcut = x
        if x.shape[-1] != filters:
            shortcut = Conv2D(filters, (1, 1), padding='same', kernel_initializer='he_normal')(shortcut)
            shortcut = BatchNormalization()(shortcut)

    x = Conv2D(filters, (3, 3), padding='same', kernel_initializer='he_normal')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(filters, (3, 3), padding='same', kernel_initializer='he_normal')(x)
    x = BatchNormalization()(x)

    if use_residual:
        x = Add()([shortcut, x])
    x = Activation('relu')(x)

    # Apply attention based on type
    if attention_type == 'cbam':
        x = cbam_block(x)
    elif attention_type == 'channel':
        x = channel_attention_only(x)
    elif attention_type == 'spatial':
        x = spatial_attention_only(x)
    # elif attention_type == 'none': no attention applied

    return x

# Plain conv block (no residual, no attention)
def conv_block(x, filters):
    x = Conv2D(filters, (3, 3), padding='same', kernel_initializer='he_normal')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(filters, (3, 3), padding='same', kernel_initializer='he_normal')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    return x

# Ablation study model builder
def build_ablation_model(input_shape, num_classes, config):
    """
    config = {
        'attention_type': 'cbam'/'channel'/'spatial'/'none',
        'use_residual': True/False,
        'use_dropout': True/False,
        'use_l2_reg': True/False,
        'dense_layers': [512, 256] or [256] or [512],
        'dropout_rates': [0.4, 0.3] or [0.5] etc.
    }
    """
    inputs = Input(shape=input_shape)

    x = Conv2D(64, (3,3), padding='same', kernel_initializer='he_normal')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((2,2))(x)

    # Apply different block types based on config
    if config['use_residual']:
        x = residual_block(x, 64, config['attention_type'])
        x = MaxPooling2D((2,2))(x)

        x = residual_block(x, 128, config['attention_type'])
        x = MaxPooling2D((2,2))(x)

        x = residual_block(x, 256, config['attention_type'])
        x = MaxPooling2D((2,2))(x)

        x = residual_block(x, 512, config['attention_type'])
    else:
        # Use plain conv blocks
        x = conv_block(x, 64)
        x = MaxPooling2D((2,2))(x)

        x = conv_block(x, 128)
        x = MaxPooling2D((2,2))(x)

        x = conv_block(x, 256)
        x = MaxPooling2D((2,2))(x)

        x = conv_block(x, 512)

    x = GlobalAveragePooling2D()(x)

    # Dense layers with ablation options
    for i, units in enumerate(config['dense_layers']):
        if config['use_l2_reg']:
            x = Dense(units, activation='relu', kernel_regularizer=regularizers.l2(0.001))(x)
        else:
            x = Dense(units, activation='relu')(x)

        if config['use_dropout'] and i < len(config['dropout_rates']):
            x = Dropout(config['dropout_rates'][i])(x)

    outputs = Dense(num_classes, activation='softmax')(x)
    model = Model(inputs, outputs)
    return model

# Ablation study configurations - optimized for your 10-epoch setup
ablation_configs = {
    'baseline': {
        'attention_type': 'cbam',
        'use_residual': True,
        'use_dropout': True,
        'use_l2_reg': True,
        'dense_layers': [512, 256],
        'dropout_rates': [0.4, 0.3]
    },
    'no_attention': {
        'attention_type': 'none',
        'use_residual': True,
        'use_dropout': True,
        'use_l2_reg': True,
        'dense_layers': [512, 256],
        'dropout_rates': [0.4, 0.3]
    },
    'channel_only': {
        'attention_type': 'channel',
        'use_residual': True,
        'use_dropout': True,
        'use_l2_reg': True,
        'dense_layers': [512, 256],
        'dropout_rates': [0.4, 0.3]
    },
    'spatial_only': {
        'attention_type': 'spatial',
        'use_residual': True,
        'use_dropout': True,
        'use_l2_reg': True,
        'dense_layers': [512, 256],
        'dropout_rates': [0.4, 0.3]
    },
    'no_residual': {
        'attention_type': 'cbam',
        'use_residual': False,
        'use_dropout': True,
        'use_l2_reg': True,
        'dense_layers': [512, 256],
        'dropout_rates': [0.4, 0.3]
    },
    'no_dropout': {
        'attention_type': 'cbam',
        'use_residual': True,
        'use_dropout': False,
        'use_l2_reg': True,
        'dense_layers': [512, 256],
        'dropout_rates': []
    },
    'no_l2_reg': {
        'attention_type': 'cbam',
        'use_residual': True,
        'use_dropout': True,
        'use_l2_reg': False,
        'dense_layers': [512, 256],
        'dropout_rates': [0.4, 0.3]
    },
    'lighter_model': {
        'attention_type': 'cbam',
        'use_residual': True,
        'use_dropout': True,
        'use_l2_reg': True,
        'dense_layers': [256],
        'dropout_rates': [0.4]
    },
    'minimal': {
        'attention_type': 'none',
        'use_residual': False,
        'use_dropout': False,
        'use_l2_reg': False,
        'dense_layers': [256],
        'dropout_rates': []
    }
}

# Training and evaluation function
def run_ablation_study(input_shape, num_classes, train_data, val_data, test_data):
    results = {}

    for config_name, config in ablation_configs.items():
        print(f"\n{'='*50}")
        print(f"Training: {config_name}")
        print(f"Config: {config}")
        print(f"{'='*50}")

        # Build model
        model = build_ablation_model(input_shape, num_classes, config)

        # Compile with early stopping
        model.compile(
            optimizer='adam',
            loss='categorical_crossentropy',
            metrics=['accuracy']
        )

        # Early stopping to prevent overfitting
        early_stopping = tf.keras.callbacks.EarlyStopping(
            monitor='val_loss',
            patience=5,
            restore_best_weights=True
        )

        # Train model
        history = model.fit(
            train_data,
            validation_data=val_data,
            epochs=50,
            callbacks=[early_stopping],
            verbose=1
        )

        # Evaluate on test set
        test_loss, test_acc = model.evaluate(test_data, verbose=0)

        # Store results
        results[config_name] = {
            'test_accuracy': test_acc,
            'test_loss': test_loss,
            'best_val_acc': max(history.history['val_accuracy']),
            'best_val_loss': min(history.history['val_loss']),
            'epochs_trained': len(history.history['loss']),
            'params': model.count_params()
        }

        print(f"Test Accuracy: {test_acc:.4f}")
        print(f"Best Val Accuracy: {max(history.history['val_accuracy']):.4f}")

    return results

# Analysis function
def analyze_ablation_results(results):
    df = pd.DataFrame(results).T
    df = df.sort_values('test_accuracy', ascending=False)

    print("\n" + "="*80)
    print("ABLATION STUDY RESULTS")
    print("="*80)
    print(df.round(4))

    # Component importance analysis
    baseline_acc = results['baseline']['test_accuracy']

    print(f"\n{'='*50}")
    print("COMPONENT IMPORTANCE ANALYSIS")
    print(f"{'='*50}")
    print(f"Baseline accuracy: {baseline_acc:.4f}")

    components = {
        'CBAM Attention': baseline_acc - results['no_attention']['test_accuracy'],
        'Channel Attention': results['channel_only']['test_accuracy'] - results['no_attention']['test_accuracy'],
        'Spatial Attention': results['spatial_only']['test_accuracy'] - results['no_attention']['test_accuracy'],
        'Residual Connections': baseline_acc - results['no_residual']['test_accuracy'],
        'Dropout': baseline_acc - results['no_dropout']['test_accuracy'],
        'L2 Regularization': baseline_acc - results['no_l2_reg']['test_accuracy'],
    }

    for component, improvement in components.items():
        print(f"{component:20}: {improvement:+.4f}")

    return df

# Complete automated ablation study runner - matching your exact setup
import tensorflow as tf
from tensorflow.keras.callbacks import LearningRateScheduler
import json
import os
import numpy as np

def save_results(results, filename='ablation_results.json'):
    """Save results to file"""
    with open(filename, 'w') as f:
        json.dump(results, f, indent=2)
    print(f"Results saved to {filename}")

def load_results(filename='ablation_results.json'):
    """Load previous results"""
    if os.path.exists(filename):
        with open(filename, 'r') as f:
            return json.load(f)
    return {}

# Learning rate scheduler - exactly as your setup
def lr_schedule(epoch):
    initial_lr = 1e-4
    k = 0.2  # Decay rate
    lr = initial_lr * np.exp(-k * epoch)
    print('Learning rate: ', lr)
    return lr

def quick_ablation_study(train_ds, val_ds, test_ds,
                        input_shape, num_classes, BATCH_SIZE,
                        resume=True, save_file='ablation_results.json'):
    """
    Complete automated ablation study - matching your exact setup

    Parameters:
    - train_ds: Training dataset (tf.data.Dataset)
    - val_ds: Validation dataset (tf.data.Dataset)
    - test_ds: Test dataset (tf.data.Dataset)
    - input_shape: (128, 128, 3)
    - num_classes: 4
    - BATCH_SIZE: Your batch size
    - resume: Whether to resume from saved results
    - save_file: File to save/load results
    """

    # Load previous results if resuming
    if resume:
        results = load_results(save_file)
        print(f"Loaded {len(results)} previous results")
    else:
        results = {}

    # Only run configs that haven't been completed
    remaining_configs = {k: v for k, v in ablation_configs.items()
                        if k not in results}

    if not remaining_configs:
        print("All ablation studies completed!")
        return load_results(save_file)

    print(f"Running {len(remaining_configs)} ablation experiments...")

    for i, (config_name, config) in enumerate(remaining_configs.items(), 1):
        print(f"\n{'='*60}")
        print(f"[{i}/{len(remaining_configs)}] Running: {config_name}")
        print(f"{'='*60}")

        try:
            # Build model - using your build_ablation_model function
            model = build_ablation_model(input_shape, num_classes, config)

            # Compile - exactly as your setup
            model.compile(
                optimizer='adam',
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy']
            )

            # Train model - exactly as your setup
            print(f"Model parameters: {model.count_params():,}")
            history = model.fit(
                train_ds,
                validation_data=val_ds,
                verbose=1,
                epochs=10,  # Same as your setup
                batch_size=BATCH_SIZE,
                callbacks=[LearningRateScheduler(lr_schedule)]
            )

            # Evaluate on test set
            test_loss, test_acc = model.evaluate(test_ds, verbose=0)

            # Store results
            results[config_name] = {
                'test_accuracy': float(test_acc),
                'test_loss': float(test_loss),
                'best_val_acc': float(max(history.history['val_accuracy'])),
                'best_val_loss': float(min(history.history['val_loss'])),
                'final_train_acc': float(history.history['accuracy'][-1]),
                'final_train_loss': float(history.history['loss'][-1]),
                'epochs_trained': len(history.history['loss']),
                'params': int(model.count_params()),
                'config': config
            }

            # Save after each experiment
            save_results(results, save_file)

            print(f"✅ {config_name} completed!")
            print(f"   Test Accuracy: {test_acc:.4f}")
            print(f"   Best Val Accuracy: {max(history.history['val_accuracy']):.4f}")
            print(f"   Epochs: {len(history.history['loss'])}")

            # Clear memory
            del model
            tf.keras.backend.clear_session()

        except Exception as e:
            print(f"❌ Error in {config_name}: {str(e)}")
            continue

    print(f"\n🎉 All ablation studies completed!")
    return results

# Simple usage function - matching your exact setup
def run_my_ablation_study(train_ds, val_ds, test_ds, BATCH_SIZE):
    """
    Simple function to run everything - exactly matching your setup
    Just call this with your datasets!
    """

    # Your exact setup
    input_shape = (128, 128, 3)
    num_classes = 5

    print(f"Using input shape: {input_shape}")
    print(f"Using number of classes: {num_classes}")
    print(f"Using batch size: {BATCH_SIZE}")

    # Run ablation study
    results = quick_ablation_study(
        train_ds, val_ds, test_ds,
        input_shape, num_classes, BATCH_SIZE
    )

    # Analyze results
    analysis_df = analyze_ablation_results(results)

    # Save analysis
    analysis_df.to_csv('ablation_analysis.csv')
    print("Analysis saved to ablation_analysis.csv")

    return results, analysis_df

# %%
results, analysis = run_my_ablation_study(train_ds, val_ds, test_ds, BATCH_SIZE)
# Out:
# Using input shape: (128, 128, 3)
# Using number of classes: 5
# Using batch size: 16
# Loaded 0 previous results
# Running 9 ablation experiments...
#
# ============================================================
# [1/9] Running: baseline
# ============================================================
# Model parameters: 5,390,537
# Learning rate:  0.0001
# Epoch 1/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 62s 102ms/step - accuracy: 0.5952 - loss: 1.8111 - val_accuracy: 0.8201 - val_loss: 1.1747 - learning_rate: 1.0000e-04
# Learning rate:  8.187307530779819e-05
# Epoch 2/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 40ms/step - accuracy: 0.9501 - loss: 0.8210 - val_accuracy: 0.9849 - val_loss: 0.6752 - learning_rate: 8.1873e-05
# Learning rate:  6.703200460356394e-05
# Epoch 3/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 41ms/step - accuracy: 0.9867 - loss: 0.6621 - val_accuracy: 0.9794 - val_loss: 0.6414 - learning_rate: 6.7032e-05
# Learning rate:  5.488116360940264e-05
# Epoch 4/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 42ms/step - accuracy: 0.9931 - loss: 0.5968 - val_accuracy: 0.9821 - val_loss: 0.6155 - learning_rate: 5.4881e-05
# Learning rate:  4.493289641172216e-05
# Epoch 5/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 40ms/step - accuracy: 0.9982 - loss: 0.5493 - val_accuracy: 0.9876 - val_loss: 0.5522 - learning_rate: 4.4933e-05
# Learning rate:  3.678794411714424e-05
# Epoch 6/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - accuracy: 0.9992 - loss: 0.5223 - val_accuracy: 0.9904 - val_loss: 0.5303 - learning_rate: 3.6788e-05
# Learning rate:  3.0119421191220204e-05
# Epoch 7/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 41ms/step - accuracy: 0.9996 - loss: 0.4992 - val_accuracy: 0.9890 - val_loss: 0.5197 - learning_rate: 3.0119e-05
# Learning rate:  2.4659696394160646e-05
# Epoch 8/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - accuracy: 0.9986 - loss: 0.4848 - val_accuracy: 0.9890 - val_loss: 0.5002 - learning_rate: 2.4660e-05
# Learning rate:  2.018965179946554e-05
# Epoch 9/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - accuracy: 0.9995 - loss: 0.4664 - val_accuracy: 0.9904 - val_loss: 0.4828 - learning_rate: 2.0190e-05
# Learning rate:  1.6529888822158655e-05
# Epoch 10/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - accuracy: 0.9989 - loss: 0.4544 - val_accuracy: 0.9890 - val_loss: 0.4761 - learning_rate: 1.6530e-05
# Results saved to ablation_results.json
# ✅ baseline completed!
#    Test Accuracy: 0.9896
#    Best Val Accuracy: 0.9904
#    Epochs: 10
#
# ============================================================
# [2/9] Running: no_attention
# ============================================================
# Model parameters: 5,302,021
# Learning rate:  0.0001
# Epoch 1/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 28s 49ms/step - accuracy: 0.7641 - loss: 1.4586 - val_accuracy: 0.6827 - val_loss: 3.0258 - learning_rate: 1.0000e-04
# Learning rate:  8.187307530779819e-05
# Epoch 2/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 40ms/step - accuracy: 0.9580 - loss: 0.8623 - val_accuracy: 0.9574 - val_loss: 0.8360 - learning_rate: 8.1873e-05
# Learning rate:  6.703200460356394e-05
# Epoch 3/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 39ms/step - accuracy: 0.9766 - loss: 0.7529 - val_accuracy: 0.9904 - val_loss: 0.6938 - learning_rate: 6.7032e-05
# Learning rate:  5.488116360940264e-05
# Epoch 4/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 40ms/step - accuracy: 0.9891 - loss: 0.6863 - val_accuracy: 0.9890 - val_loss: 0.6711 - learning_rate: 5.4881e-05
# Learning rate:  4.493289641172216e-05
# Epoch 5/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 40ms/step - accuracy: 0.9963 - loss: 0.6501 - val_accuracy: 0.9794 - val_loss: 0.7182 - learning_rate: 4.4933e-05
# Learning rate:  3.678794411714424e-05
# Epoch 6/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 40ms/step - accuracy: 0.9953 - loss: 0.6329 - val_accuracy: 0.9918 - val_loss: 0.6283 - learning_rate: 3.6788e-05
# Learning rate:  3.0119421191220204e-05
# Epoch 7/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 39ms/step - accuracy: 0.9975 - loss: 0.6149 - val_accuracy: 0.9918 - val_loss: 0.6093 - learning_rate: 3.0119e-05
# Learning rate:  2.4659696394160646e-05
# Epoch 8/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 39ms/step - accuracy: 0.9985 - loss: 0.5911 - val_accuracy: 0.9959 - val_loss: 0.5916 - learning_rate: 2.4660e-05
# Learning rate:  2.018965179946554e-05
# Epoch 9/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - accuracy: 0.9997 - loss: 0.5738 - val_accuracy: 0.9931 - val_loss: 0.5825 - learning_rate: 2.0190e-05
# Learning rate:  1.6529888822158655e-05
# Epoch 10/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 40ms/step - accuracy: 0.9993 - loss: 0.5692 - val_accuracy: 0.9945 - val_loss: 0.5747 - learning_rate: 1.6530e-05
# Results saved to ablation_results.json
# ✅ no_attention completed!
#    Test Accuracy: 0.9948
#    Best Val Accuracy: 0.9959
#    Epochs: 10
#
# ============================================================
# [3/9] Running: channel_only
# ============================================================
# Model parameters: 5,390,141
# Learning rate:  0.0001
# Epoch 1/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 37s 65ms/step - accuracy: 0.7367 - loss: 1.5195 - val_accuracy: 0.7363 - val_loss: 2.1711 - learning_rate: 1.0000e-04
# Learning rate:  8.187307530779819e-05
# Epoch 2/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 40ms/step - accuracy: 0.9577 - loss: 0.8938 - val_accuracy: 0.8626 - val_loss: 1.1513 - learning_rate: 8.1873e-05
# Learning rate:  6.703200460356394e-05
# Epoch 3/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 41ms/step - accuracy: 0.9888 - loss: 0.7544 - val_accuracy: 0.9313 - val_loss: 0.9037 - learning_rate: 6.7032e-05
# Learning rate:  5.488116360940264e-05
# Epoch 4/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - accuracy: 0.9922 - loss: 0.7055 - val_accuracy: 0.9918 - val_loss: 0.6773 - learning_rate: 5.4881e-05
# Learning rate:  4.493289641172216e-05
# Epoch 5/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 40ms/step - accuracy: 0.9963 - loss: 0.6556 - val_accuracy: 0.9492 - val_loss: 0.8001 - learning_rate: 4.4933e-05
# Learning rate:  3.678794411714424e-05
# Epoch 6/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 40ms/step - accuracy: 0.9991 - loss: 0.6274 - val_accuracy: 0.9959 - val_loss: 0.6316 - learning_rate: 3.6788e-05
# Learning rate:  3.0119421191220204e-05
# Epoch 7/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 40ms/step - accuracy: 0.9995 - loss: 0.6102 - val_accuracy: 0.9945 - val_loss: 0.6123 - learning_rate: 3.0119e-05
# Learning rate:  2.4659696394160646e-05
# Epoch 8/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - accuracy: 0.9987 - loss: 0.5896 - val_accuracy: 0.9959 - val_loss: 0.5913 - learning_rate: 2.4660e-05
# Learning rate:  2.018965179946554e-05
# Epoch 9/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 40ms/step - accuracy: 0.9996 - loss: 0.5755 - val_accuracy: 0.9973 - val_loss: 0.5780 - learning_rate: 2.0190e-05
# Learning rate:  1.6529888822158655e-05
# Epoch 10/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 40ms/step - accuracy: 0.9999 - loss: 0.5621 - val_accuracy: 0.9945 - val_loss: 0.5719 - learning_rate: 1.6530e-05
# Results saved to ablation_results.json
# ✅ channel_only completed!
#    Test Accuracy: 0.9948
#    Best Val Accuracy: 0.9973
#    Epochs: 10
#
# ============================================================
# [4/9] Running: spatial_only
# ============================================================
# Model parameters: 5,302,417
# Learning rate:  0.0001
# Epoch 1/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 33s 57ms/step - accuracy: 0.7057 - loss: 1.6358 - val_accuracy: 0.6786 - val_loss: 1.7584 - learning_rate: 1.0000e-04
# Learning rate:  8.187307530779819e-05
# Epoch 2/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 29s 41ms/step - accuracy: 0.9696 - loss: 0.8229 - val_accuracy: 0.8530 - val_loss: 1.1186 - learning_rate: 8.1873e-05
# Learning rate:  6.703200460356394e-05
# Epoch 3/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - accuracy: 0.9852 - loss: 0.7150 - val_accuracy: 0.9890 - val_loss: 0.6776 - learning_rate: 6.7032e-05
# Learning rate:  5.488116360940264e-05
# Epoch 4/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - accuracy: 0.9952 - loss: 0.6490 - val_accuracy: 0.9890 - val_loss: 0.6414 - learning_rate: 5.4881e-05
# Learning rate:  4.493289641172216e-05
# Epoch 5/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - accuracy: 0.9989 - loss: 0.6055 - val_accuracy: 0.9890 - val_loss: 0.6138 - learning_rate: 4.4933e-05
# Learning rate:  3.678794411714424e-05
# Epoch 6/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 41ms/step - accuracy: 0.9993 - loss: 0.5766 - val_accuracy: 0.9863 - val_loss: 0.5979 - learning_rate: 3.6788e-05
# Learning rate:  3.0119421191220204e-05
# Epoch 7/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - accuracy: 0.9997 - loss: 0.5545 - val_accuracy: 0.9918 - val_loss: 0.5773 - learning_rate: 3.0119e-05
# Learning rate:  2.4659696394160646e-05
# Epoch 8/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 41ms/step - accuracy: 1.0000 - loss: 0.5357 - val_accuracy: 0.9918 - val_loss: 0.5592 - learning_rate: 2.4660e-05
# Learning rate:  2.018965179946554e-05
# Epoch 9/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - accuracy: 1.0000 - loss: 0.5195 - val_accuracy: 0.9918 - val_loss: 0.5461 - learning_rate: 2.0190e-05
# Learning rate:  1.6529888822158655e-05
# Epoch 10/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 41ms/step - accuracy: 1.0000 - loss: 0.5060 - val_accuracy: 0.9904 - val_loss: 0.5319 - learning_rate: 1.6530e-05
# Results saved to ablation_results.json
# ✅ spatial_only completed!
#    Test Accuracy: 1.0000
#    Best Val Accuracy: 0.9918
#    Epochs: 10
#
# ============================================================
# [5/9] Running: no_residual
# ============================================================
# Model parameters: 5,125,509
# Learning rate:  0.0001
# Epoch 1/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 24s 48ms/step - accuracy: 0.7664 - loss: 1.4642 - val_accuracy: 0.8008 - val_loss: 1.4549 - learning_rate: 1.0000e-04
# Learning rate:  8.187307530779819e-05
# Epoch 2/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 12s 37ms/step - accuracy: 0.9679 - loss: 0.8331 - val_accuracy: 0.9011 - val_loss: 1.0060 - learning_rate: 8.1873e-05
# Learning rate:  6.703200460356394e-05
# Epoch 3/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 37ms/step - accuracy: 0.9785 - loss: 0.7424 - val_accuracy: 0.9766 - val_loss: 0.7128 - learning_rate: 6.7032e-05
# Learning rate:  5.488116360940264e-05
# Epoch 4/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 8s 37ms/step - accuracy: 0.9915 - loss: 0.6724 - val_accuracy: 0.8997 - val_loss: 0.9983 - learning_rate: 5.4881e-05
# Learning rate:  4.493289641172216e-05
# Epoch 5/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 8s 37ms/step - accuracy: 0.9909 - loss: 0.6478 - val_accuracy: 0.9904 - val_loss: 0.6356 - learning_rate: 4.4933e-05
# Learning rate:  3.678794411714424e-05
# Epoch 6/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - accuracy: 0.9981 - loss: 0.5998 - val_accuracy: 0.9986 - val_loss: 0.5950 - learning_rate: 3.6788e-05
# Learning rate:  3.0119421191220204e-05
# Epoch 7/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 38ms/step - accuracy: 0.9999 - loss: 0.5781 - val_accuracy: 0.9890 - val_loss: 0.5945 - learning_rate: 3.0119e-05
# Learning rate:  2.4659696394160646e-05
# Epoch 8/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 8s 37ms/step - accuracy: 0.9999 - loss: 0.5623 - val_accuracy: 0.9945 - val_loss: 0.5682 - learning_rate: 2.4660e-05
# Learning rate:  2.018965179946554e-05
# Epoch 9/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 37ms/step - accuracy: 0.9998 - loss: 0.5472 - val_accuracy: 0.9973 - val_loss: 0.5505 - learning_rate: 2.0190e-05
# Learning rate:  1.6529888822158655e-05
# Epoch 10/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 8s 37ms/step - accuracy: 0.9996 - loss: 0.5345 - val_accuracy: 0.9986 - val_loss: 0.5395 - learning_rate: 1.6530e-05
# Results saved to ablation_results.json
# ✅ no_residual completed!
#    Test Accuracy: 0.9987
#    Best Val Accuracy: 0.9986
#    Epochs: 10
#
# ============================================================
# [6/9] Running: no_dropout
# ============================================================
# Model parameters: 5,390,537
# Learning rate:  0.0001
# Epoch 1/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 39s 68ms/step - accuracy: 0.7080 - loss: 1.5509 - val_accuracy: 0.5659 - val_loss: 1.8388 - learning_rate: 1.0000e-04
# Learning rate:  8.187307530779819e-05
# Epoch 2/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - accuracy: 0.9743 - loss: 0.7552 - val_accuracy: 0.9080 - val_loss: 0.9148 - learning_rate: 8.1873e-05
# Learning rate:  6.703200460356394e-05
# Epoch 3/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 41ms/step - accuracy: 0.9871 - loss: 0.6347 - val_accuracy: 0.9547 - val_loss: 0.6627 - learning_rate: 6.7032e-05
# Learning rate:  5.488116360940264e-05
# Epoch 4/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - accuracy: 0.9945 - loss: 0.5610 - val_accuracy: 0.9890 - val_loss: 0.5524 - learning_rate: 5.4881e-05
# Learning rate:  4.493289641172216e-05
# Epoch 5/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - accuracy: 0.9977 - loss: 0.5128 - val_accuracy: 0.9918 - val_loss: 0.5022 - learning_rate: 4.4933e-05
# Learning rate:  3.678794411714424e-05
# Epoch 6/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 42ms/step - accuracy: 0.9998 - loss: 0.4746 - val_accuracy: 0.9890 - val_loss: 0.4790 - learning_rate: 3.6788e-05
# Learning rate:  3.0119421191220204e-05
# Epoch 7/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 41ms/step - accuracy: 0.9998 - loss: 0.4491 - val_accuracy: 0.9918 - val_loss: 0.4541 - learning_rate: 3.0119e-05
# Learning rate:  2.4659696394160646e-05
# Epoch 8/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - accuracy: 0.9998 - loss: 0.4285 - val_accuracy: 0.9918 - val_loss: 0.4364 - learning_rate: 2.4660e-05
# Learning rate:  2.018965179946554e-05
# Epoch 9/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 41ms/step - accuracy: 0.9999 - loss: 0.4102 - val_accuracy: 0.9931 - val_loss: 0.4191 - learning_rate: 2.0190e-05
# Learning rate:  1.6529888822158655e-05
# Epoch 10/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 41ms/step - accuracy: 1.0000 - loss: 0.3952 - val_accuracy: 0.9918 - val_loss: 0.4077 - learning_rate: 1.6530e-05
# Results saved to ablation_results.json
# ✅ no_dropout completed!
#    Test Accuracy: 0.9948
#    Best Val Accuracy: 0.9931
#    Epochs: 10
#
# ============================================================
# [7/9] Running: no_l2_reg
# ============================================================
# Model parameters: 5,390,537
# Learning rate:  0.0001
# Epoch 1/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 40s 67ms/step - accuracy: 0.6972 - loss: 0.8182 - val_accuracy: 0.7981 - val_loss: 0.5283 - learning_rate: 1.0000e-04
# Learning rate:  8.187307530779819e-05
# Epoch 2/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 24s 42ms/step - accuracy: 0.9643 - loss: 0.1256 - val_accuracy: 0.8255 - val_loss: 0.5382 - learning_rate: 8.1873e-05
# Learning rate:  6.703200460356394e-05
# Epoch 3/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - accuracy: 0.9825 - loss: 0.0647 - val_accuracy: 0.9849 - val_loss: 0.0441 - learning_rate: 6.7032e-05
# Learning rate:  5.488116360940264e-05
# Epoch 4/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - accuracy: 0.9924 - loss: 0.0326 - val_accuracy: 0.9821 - val_loss: 0.0476 - learning_rate: 5.4881e-05
# Learning rate:  4.493289641172216e-05
# Epoch 5/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - accuracy: 0.9981 - loss: 0.0156 - val_accuracy: 0.9918 - val_loss: 0.0426 - learning_rate: 4.4933e-05
# Learning rate:  3.678794411714424e-05
# Epoch 6/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 42ms/step - accuracy: 0.9995 - loss: 0.0103 - val_accuracy: 0.9945 - val_loss: 0.0291 - learning_rate: 3.6788e-05
# Learning rate:  3.0119421191220204e-05
# Epoch 7/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 43ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.9931 - val_loss: 0.0324 - learning_rate: 3.0119e-05
# Learning rate:  2.4659696394160646e-05
# Epoch 8/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 44ms/step - accuracy: 0.9999 - loss: 0.0031 - val_accuracy: 0.9945 - val_loss: 0.0280 - learning_rate: 2.4660e-05
# Learning rate:  2.018965179946554e-05
# Epoch 9/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - accuracy: 0.9988 - loss: 0.0043 - val_accuracy: 0.9973 - val_loss: 0.0286 - learning_rate: 2.0190e-05
# Learning rate:  1.6529888822158655e-05
# Epoch 10/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - accuracy: 0.9998 - loss: 0.0026 - val_accuracy: 0.9945 - val_loss: 0.0277 - learning_rate: 1.6530e-05
# Results saved to ablation_results.json
# ✅ no_l2_reg completed!
#    Test Accuracy: 0.9909
#    Best Val Accuracy: 0.9973
#    Epochs: 10
#
# ============================================================
# [8/9] Running: lighter_model
# ============================================================
# Model parameters: 5,127,881
# Learning rate:  0.0001
# Epoch 1/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 40s 66ms/step - accuracy: 0.7292 - loss: 1.1357 - val_accuracy: 0.8695 - val_loss: 0.6711 - learning_rate: 1.0000e-04
# Learning rate:  8.187307530779819e-05
# Epoch 2/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 24s 43ms/step - accuracy: 0.9655 - loss: 0.4110 - val_accuracy: 0.9849 - val_loss: 0.3529 - learning_rate: 8.1873e-05
# Learning rate:  6.703200460356394e-05
# Epoch 3/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - accuracy: 0.9861 - loss: 0.3218 - val_accuracy: 0.9203 - val_loss: 0.4698 - learning_rate: 6.7032e-05
# Learning rate:  5.488116360940264e-05
# Epoch 4/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - accuracy: 0.9911 - loss: 0.2931 - val_accuracy: 0.9712 - val_loss: 0.3458 - learning_rate: 5.4881e-05
# Learning rate:  4.493289641172216e-05
# Epoch 5/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 43ms/step - accuracy: 0.9973 - loss: 0.2619 - val_accuracy: 0.9272 - val_loss: 0.4616 - learning_rate: 4.4933e-05
# Learning rate:  3.678794411714424e-05
# Epoch 6/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - accuracy: 0.9972 - loss: 0.2532 - val_accuracy: 0.9973 - val_loss: 0.2509 - learning_rate: 3.6788e-05
# Learning rate:  3.0119421191220204e-05
# Epoch 7/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - accuracy: 0.9998 - loss: 0.2335 - val_accuracy: 0.9945 - val_loss: 0.2494 - learning_rate: 3.0119e-05
# Learning rate:  2.4659696394160646e-05
# Epoch 8/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 43ms/step - accuracy: 0.9999 - loss: 0.2236 - val_accuracy: 0.9959 - val_loss: 0.2334 - learning_rate: 2.4660e-05
# Learning rate:  2.018965179946554e-05
# Epoch 9/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 9s 42ms/step - accuracy: 0.9998 - loss: 0.2177 - val_accuracy: 0.9945 - val_loss: 0.2293 - learning_rate: 2.0190e-05
# Learning rate:  1.6529888822158655e-05
# Epoch 10/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 43ms/step - accuracy: 1.0000 - loss: 0.2098 - val_accuracy: 0.9959 - val_loss: 0.2204 - learning_rate: 1.6530e-05
# Results saved to ablation_results.json
# ✅ lighter_model completed!
#    Test Accuracy: 0.9987
#    Best Val Accuracy: 0.9973
#    Epochs: 10
#
# ============================================================
# [9/9] Running: minimal
# ============================================================
# Model parameters: 4,862,853
# Learning rate:  0.0001
# Epoch 1/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 23s 49ms/step - accuracy: 0.8546 - loss: 0.4321 - val_accuracy: 0.9505 - val_loss: 0.1742 - learning_rate: 1.0000e-04
# Learning rate:  8.187307530779819e-05
# Epoch 2/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 14s 37ms/step - accuracy: 0.9746 - loss: 0.0873 - val_accuracy: 0.9080 - val_loss: 0.3286 - learning_rate: 8.1873e-05
# Learning rate:  6.703200460356394e-05
# Epoch 3/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - accuracy: 0.9873 - loss: 0.0398 - val_accuracy: 0.9478 - val_loss: 0.1464 - learning_rate: 6.7032e-05
# Learning rate:  5.488116360940264e-05
# Epoch 4/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 8s 37ms/step - accuracy: 0.9917 - loss: 0.0283 - val_accuracy: 0.9890 - val_loss: 0.0437 - learning_rate: 5.4881e-05
# Learning rate:  4.493289641172216e-05
# Epoch 5/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 37ms/step - accuracy: 0.9990 - loss: 0.0127 - val_accuracy: 0.9973 - val_loss: 0.0191 - learning_rate: 4.4933e-05
# Learning rate:  3.678794411714424e-05
# Epoch 6/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 8s 37ms/step - accuracy: 0.9998 - loss: 0.0047 - val_accuracy: 0.9973 - val_loss: 0.0168 - learning_rate: 3.6788e-05
# Learning rate:  3.0119421191220204e-05
# Epoch 7/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 36ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.9959 - val_loss: 0.0142 - learning_rate: 3.0119e-05
# Learning rate:  2.4659696394160646e-05
# Epoch 8/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 37ms/step - accuracy: 0.9999 - loss: 0.0025 - val_accuracy: 0.9973 - val_loss: 0.0144 - learning_rate: 2.4660e-05
# Learning rate:  2.018965179946554e-05
# Epoch 9/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 8s 38ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9973 - val_loss: 0.0123 - learning_rate: 2.0190e-05
# Learning rate:  1.6529888822158655e-05
# Epoch 10/10
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 10s 37ms/step - accuracy: 0.9990 - loss: 0.0057 - val_accuracy: 0.9973 - val_loss: 0.0143 - learning_rate: 1.6530e-05
# Results saved to ablation_results.json
# ✅ minimal completed!
#    Test Accuracy: 0.9974
#    Best Val Accuracy: 0.9973
#    Epochs: 10
#
# 🎉 All ablation studies completed!
#
# ================================================================================
# ABLATION STUDY RESULTS
# ================================================================================
#               test_accuracy test_loss best_val_acc best_val_loss  \
# spatial_only            1.0  0.499436     0.991758      0.531867
# no_residual        0.998698  0.529418     0.998626      0.539549
# lighter_model      0.998698  0.210514     0.997253      0.220359
# minimal            0.997396  0.009999     0.997253      0.012345
# no_attention       0.994792  0.562893     0.995879      0.574748
# channel_only       0.994792  0.557844     0.997253      0.571861
# no_dropout         0.994792  0.401946     0.993132      0.407732
# no_l2_reg          0.990885  0.030009     0.997253      0.027707
# baseline           0.989583  0.478795     0.990385      0.476139
#
#               final_train_acc final_train_loss epochs_trained   params  \
# spatial_only              1.0         0.502919             10  5302417
# no_residual          0.999429         0.532563             10  5125509
# lighter_model        0.999715          0.20945             10  5127881
# minimal              0.999715         0.002791             10  4862853
# no_attention         0.999715          0.56237             10  5302021
# channel_only         0.999715         0.560457             10  5390141
# no_dropout           0.999715         0.393161             10  5390537
# no_l2_reg            0.999715         0.002995             10  5390537
# baseline             0.999715         0.448214             10  5390537
#
#                                                           config
# spatial_only   {'attention_type': 'spatial', 'use_residual': ...
# no_residual    {'attention_type': 'cbam', 'use_residual': Fal...
# lighter_model  {'attention_type': 'cbam', 'use_residual': Tru...
# minimal        {'attention_type': 'none', 'use_residual': Fal...
# no_attention   {'attention_type': 'none', 'use_residual': Tru...
# channel_only   {'attention_type': 'channel', 'use_residual': ...
# no_dropout     {'attention_type': 'cbam', 'use_residual': Tru...
# no_l2_reg      {'attention_type': 'cbam', 'use_residual': Tru...
# baseline       {'attention_type': 'cbam', 'use_residual': Tru...
#
# ==================================================
# COMPONENT IMPORTANCE ANALYSIS
# ==================================================
# Baseline accuracy: 0.9896
# CBAM Attention      : -0.0052
# Channel Attention   : +0.0000
# Spatial Attention   : +0.0052
# Residual Connections: -0.0091
# Dropout             : -0.0052
# L2 Regularization   : -0.0013
# Analysis saved to ablation_analysis.csv
